# %%
# Install Package
# !pip install twint
# !pip install nest_asyncio

# Fix Issue with twint 20.1.20 from pip --> upgrade to 20.1.21 directly from git
# !pip install --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Collecting twint
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python310\\Scripts\\normalizer.exe' -> 'C:\\Python310\\Scripts\\normalizer.exe.deleteme'
#
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
#   Using cached twint-2.1.20.tar.gz (31 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.3-cp310-cp310-win_amd64.whl (319 kB)
# Collecting aiodns
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting cchardet
#   Downloading cchardet-2.1.7.tar.gz (653 kB)
# Collecting elasticsearch
#   Using cached elasticsearch-8.5.3-py3-none-any.whl (385 kB)
# Collecting pysocks
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pandas
#   Downloading pandas-1.5.2-cp310-cp310-win_amd64.whl (10.4 MB)
# Collecting aiohttp_socks
#   Using cached aiohttp_socks-0.7.1-py3-none-any.whl (9.3 kB)
# Collecting schedule
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Collecting geopy
#   Using cached geopy-2.3.0-py3-none-any.whl (119 kB)
# Collecting fake-useragent
#   Using cached fake_useragent-1.1.1-py3-none-any.whl (50 kB)
# Collecting googletransx
#   Using cached googletransx-2.4.2.tar.gz (13 kB)
# Collecting pycares>=4.0.0
#   Downloading pycares-4.3.0-cp310-cp310-win_amd64.whl (76 kB)
# Collecting cffi>=1.5.0
#   Downloading cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp310-cp310-win_amd64.whl (56 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.3-cp310-cp310-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Collecting idna>=2.0
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
# Collecting python-socks[asyncio]<3.0.0,>=2.0.0
#   Using cached python_socks-2.0.3-py3-none-any.whl (49 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting elastic-transport<9,>=8
#   Using cached elastic_transport-8.4.0-py3-none-any.whl (59 kB)
# Collecting certifi
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting urllib3<2,>=1.26.2
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting geographiclib<3,>=1.52
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Collecting requests
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python310\lib\site-packages (from pandas->twint) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\python310\lib\site-packages (from pandas->twint) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->twint) (1.16.0)
# Using legacy 'setup.py install' for twint, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for cchardet, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for googletransx, since package 'wheel' is not installed.
# Installing collected packages: pycparser, multidict, idna, frozenlist, yarl, urllib3, python-socks, charset-normalizer, cffi, certifi, attrs, async-timeout, aiosignal, soupsieve, requests, pytz, pycares, geographiclib, elastic-transport, aiohttp, schedule, pysocks, pandas, googletransx, geopy, fake-useragent, elasticsearch, cchardet, beautifulsoup4, aiohttp-socks, aiodns, twint
# Requirement already satisfied: nest_asyncio in c:\users\radit\appdata\roaming\python\python310\site-packages (1.5.6)
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Running command git fetch -q --tags
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git reset --hard -q origin/master
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Radit\\AppData\\Local\\Temp\\pip-install-if3e6l67\\googletransx_4ca1c4b7a31645c0812804686dade4e4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Radit\\AppData\\Local\\Temp\\pip-install-if3e6l67\\googletransx_4ca1c4b7a31645c0812804686dade4e4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Radit\AppData\Local\Temp\pip-record-f78bar51\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python310\Include\googletransx'
#          cwd: C:\Users\Radit\AppData\Local\Temp\pip-install-if3e6l67\googletransx_4ca1c4b7a31645c0812804686dade4e4\
#     Complete output (53 lines):
#     C:\Python310\lib\site-packages\setuptools\dist.py:717: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#       warnings.warn(
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib
#     creating build\lib\googletransx
#     copying googletransx\adapters.py -> build\lib\googletransx
#     copying googletransx\client.py -> build\lib\googletransx
#   Updating d:\college\5th semester\machine learning\w17 - uas\js15_uas\src\twint clone (to revision origin/master)
# Collecting aiohttp
#   Using cached aiohttp-3.8.3-cp310-cp310-win_amd64.whl (319 kB)
# Collecting aiodns
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting cchardet
#   Using cached cchardet-2.1.7.tar.gz (653 kB)
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting elasticsearch
#   Using cached elasticsearch-8.5.3-py3-none-any.whl (385 kB)
# Collecting pysocks
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pandas
#   Using cached pandas-1.5.2-cp310-cp310-win_amd64.whl (10.4 MB)
# Collecting aiohttp_socks
#   Using cached aiohttp_socks-0.7.1-py3-none-any.whl (9.3 kB)
# Collecting schedule
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Collecting geopy
#   Using cached geopy-2.3.0-py3-none-any.whl (119 kB)
# Collecting fake-useragent
#   Using cached fake_useragent-1.1.1-py3-none-any.whl (50 kB)
# Collecting googletransx
#   Using cached googletransx-2.4.2.tar.gz (13 kB)
# Collecting pycares>=4.0.0
#   Using cached pycares-4.3.0-cp310-cp310-win_amd64.whl (76 kB)
# Collecting cffi>=1.5.0
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Requirement already satisfied: pycparser in c:\python310\lib\site-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->twint) (2.21)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python310\lib\site-packages (from aiohttp->twint) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\python310\lib\site-packages (from aiohttp->twint) (1.8.2)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\python310\lib\site-packages (from aiohttp->twint) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python310\lib\site-packages (from aiohttp->twint) (6.0.3)
# Collecting attrs>=17.3.0
#   Using cached attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna>=2.0 in c:\python310\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->twint) (3.4)
# Requirement already satisfied: python-socks[asyncio]<3.0.0,>=2.0.0 in c:\python310\lib\site-packages (from aiohttp_socks->twint) (2.0.3)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting elastic-transport<9,>=8
#   Using cached elastic_transport-8.4.0-py3-none-any.whl (59 kB)
# Requirement already satisfied: urllib3<2,>=1.26.2 in c:\python310\lib\site-packages (from elastic-transport<9,>=8->elasticsearch->twint) (1.26.13)
# Collecting certifi
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting geographiclib<3,>=1.52
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python310\lib\site-packages (from pandas->twint) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\python310\lib\site-packages (from pandas->twint) (1.23.4)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->twint) (1.16.0)
# Using legacy 'setup.py install' for cchardet, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for googletransx, since package 'wheel' is not installed.
# Installing collected packages: cffi, certifi, attrs, async-timeout, aiosignal, soupsieve, requests, pytz, pycares, geographiclib, elastic-transport, aiohttp, schedule, pysocks, pandas, googletransx, geopy, fake-useragent, elasticsearch, dataclasses, cchardet, beautifulsoup4, aiohttp-socks, aiodns, twint
#     Running setup.py install for googletransx: started
#     Running setup.py install for googletransx: finished with status 'error'
#     copying googletransx\compat.py -> build\lib\googletransx
#     copying googletransx\constants.py -> build\lib\googletransx
#     copying googletransx\gtoken.py -> build\lib\googletransx
#     copying googletransx\models.py -> build\lib\googletransx
#     copying googletransx\urls.py -> build\lib\googletransx
#     copying googletransx\utils.py -> build\lib\googletransx
#     copying googletransx\__init__.py -> build\lib\googletransx
#     running build_scripts
#     creating build\scripts-3.10
#     copying and adjusting translate -> build\scripts-3.10
#     running install_lib
#     creating C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\adapters.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\client.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\compat.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\constants.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\gtoken.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\models.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\urls.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\utils.py -> C:\Python310\Lib\site-packages\googletransx
#     copying build\lib\googletransx\__init__.py -> C:\Python310\Lib\site-packages\googletransx
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\adapters.py to adapters.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\client.py to client.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\compat.py to compat.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\constants.py to constants.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\gtoken.py to gtoken.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\models.py to models.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\urls.py to urls.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\utils.py to utils.cpython-310.pyc
#     byte-compiling C:\Python310\Lib\site-packages\googletransx\__init__.py to __init__.cpython-310.pyc
#     running install_egg_info
#     running egg_info
#     writing googletransx.egg-info\PKG-INFO
#     writing dependency_links to googletransx.egg-info\dependency_links.txt
#     writing requirements to googletransx.egg-info\requires.txt
#     writing top-level names to googletransx.egg-info\top_level.txt
#     reading manifest file 'googletransx.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'googletransx.egg-info\SOURCES.txt'
#     Copying googletransx.egg-info to C:\Python310\Lib\site-packages\googletransx-2.4.2-py3.10.egg-info
#     running install_scripts
#     copying build\scripts-3.10\translate -> C:\Python310\Scripts
#     error: could not create 'C:\Python310\Scripts\translate': Permission denied
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Python310\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Radit\\AppData\\Local\\Temp\\pip-install-if3e6l67\\googletransx_4ca1c4b7a31645c0812804686dade4e4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Radit\\AppData\\Local\\Temp\\pip-install-if3e6l67\\googletransx_4ca1c4b7a31645c0812804686dade4e4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Radit\AppData\Local\Temp\pip-record-f78bar51\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Python310\Include\googletransx' Check the logs for full command output.
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# inisiasi obyek
c = twint.Config()

# config scrap
c.Username = "collegemenfess"
# c.Since = "2022-12-02"
# c.Until = "2022-12-05"
c.Limit = 100
c.Store_csv = True
c.Output = "colle_scrap.csv"

# run scrap
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-41426060ec84> in <module>
# ----> 1 import twint
#       2 import nest_asyncio
#       3 nest_asyncio.apply()
#       4
#       5 # inisiasi obyek
#
# ModuleNotFoundError: No module named 'twint'
